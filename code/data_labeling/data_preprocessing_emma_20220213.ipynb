# %%
import numpy as np
import matplotlib.pyplot as plt

from hmmlearn import hmm
import yfinance as yf
import pandas as pd

# %%
df = yf.download('^RUA',start = '2000-01-01')
df.reset_index(inplace = True) #resetting index
df.head() # display
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2000-01-03  793.309998  798.419983  776.400024  786.200012  786.200012
# 1 2000-01-04  786.270020  786.270020  754.739990  755.799988  755.799988
# 2 2000-01-05  755.799988  762.210022  742.820007  757.090027  757.090027
# 3 2000-01-06  757.090027  761.960022  751.590027  756.729980  756.729980
# 4 2000-01-07  756.729980  777.250000  755.460022  777.250000  777.250000
#
#    Volume
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['pct_ret'] = df['Adj Close'].pct_change()
df['state'] = df['pct_ret'].apply(lambda x: 2 if (x > 0.001)\
else (0 if (x < -0.001)\
else 1))
df.dropna(inplace = True)
df.tail()
# Out:
#            Date         Open         High          Low        Close  \
# 5526 2022-01-31  2566.699951  2622.290039  2558.979980  2621.969971
# 5527 2022-02-01  2622.000000  2644.320068  2602.290039  2642.229980
# 5528 2022-02-02  2642.379883  2662.360107  2634.629883  2659.229980
# 5529 2022-02-03  2658.280029  2658.280029  2590.780029  2594.100098
# 5530 2022-02-04  2593.709961  2632.350098  2580.100098  2610.659912
#
#         Adj Close  Volume   pct_ret  state
# 5526  2621.969971       0  0.021498      2
# 5527  2642.229980       0  0.007727      2
# 5528  2659.229980       0  0.006434      2
# 5529  2594.100098       0 -0.024492      0
# 5530  2610.659912       0  0.006384      2

# %%
X = df[['Adj Close','pct_ret']].to_numpy()
y = data['state']

# %%
# Build an HMM instance and set parameters
remodel = hmm.GaussianHMM(n_components=3, covariance_type="full", n_iter=100)
remodel.fit(X)

Z2 = remodel.predict(X)

# %%
Z = pd.DataFrame(Z2)
Z.value_counts()
# Out:
# 0    3345
# 2    1104
# 1    1081
# dtype: int64

# %%
y.value_counts()
# Out:
# up           2644
# down         2215
# no_change     671
# Name: state, dtype: int64

# %%
model1 = hmm.MultinomialHMM(n_components=3)
model1.fit(X,y)

# y_pred = model1.predict(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7312/846045811.py in <module>
#       1 model1 = hmm.MultinomialHMM(n_components=3)
# ----> 2 model1.fit(X,y)
#       3
#       4 # y_pred = model1.predict(X)
#
# ~\anaconda3\lib\site-packages\hmmlearn\hmm.py in <lambda>(*args, **kwargs)
#     323     else:
#     324         wrapper = functools.wraps(func)(
# --> 325             lambda *args, **kwargs: func(*args, **kwargs))
#     326         wrapper.__doc__ = (
#     327             doc.replace("(n_samples, n_features)", "(n_samples, 1)")
#
# ~\anaconda3\lib\site-packages\hmmlearn\base.py in fit(self, X, lengths)
#     439         """
#     440         X = check_array(X)
# --> 441         self._init(X, lengths=lengths)
#     442         self._check()
#     443
#
# ~\anaconda3\lib\site-packages\hmmlearn\hmm.py in _init(self, X, lengths)
#     431
# ...

# %%
import seqlearn
# from seqlearn import hmm
model1 = seqlearn.hmm.MultinomialHMM(n_components=3)
model1.fit(X)

y_pred = model1.predict(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7312/3639220284.py in <module>
#       1 import seqlearn
#       2 # from seqlearn import hmm
# ----> 3 model1 = seqlearn.hmm.MultinomialHMM(n_components=3)
#       4 model1.fit(X)
#       5
#
# AttributeError: module 'seqlearn' has no attribute 'hmm'

# %%
from ta import add_all_ta_features
from ta.utils import dropna
from ta.volatility import BollingerBands

# %%
import pandas as pd
from ta import add_all_ta_features
from ta.utils import dropna
import yfinance as yf

df = yf.download('^RUA',start = '2000-01-01')
df.reset_index(inplace = True) #resetting index
df.head() # display

# Add ta features filling NaN values
df = add_all_ta_features(
    df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\lemon\anaconda3\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\lemon\anaconda3\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2000-01-03   793.309998   798.419983   776.400024   786.200012
# 1    2000-01-04   786.270020   786.270020   754.739990   755.799988
# 2    2000-01-05   755.799988   762.210022   742.820007   757.090027
# 3    2000-01-06   757.090027   761.960022   751.590027   756.729980
# 4    2000-01-07   756.729980   777.250000   755.460022   777.250000
# ...         ...          ...          ...          ...          ...
# 5531 2022-02-07  2610.709961  2625.189941  2596.939941  2603.570068
# 5532 2022-02-08  2602.929932  2633.120117  2593.729980  2627.810059
# 5533 2022-02-09  2628.360107  2670.100098  2628.360107  2669.320068
# 5534 2022-02-10  2668.489990  2674.540039  2610.729980  2622.479980
# 5535 2022-02-11  2622.699951  2635.560059  2563.649902  2573.780029
#
#         Adj Close  Volume    volume_adi  volume_obv  volume_cmf  ...  \
# 0      786.200012       0 -0.000000e+00           0    0.000000  ...
# ...

# %%
def train(df, parameter):
    X = ['','']
    y = 

    for parameter
        model.fit
        model.predict
    
    # compare

    return model
